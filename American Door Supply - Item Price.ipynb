# %%
import pandas as pd
import numpy as np
misys = pd.read_csv('C:\\Users\\robjac\\Documents\\Jupyter\\Data\\MIITEM.csv')

# %%
misys = misys.drop(['custFld1','cLast','cStd','cAvg','cLand','xdesc', 'ref', 'pick', 'sales', 'uOfM', 'poUOfM',
       'uConvFact', 'glId', 'segId', 'cycle', 'type', 'revId', 'track', 'lead',
       'minLvl', 'maxLvl', 'ordLvl', 'ordQty', 'variance', 'lotSz','unitWgt', 'locId', 'suplId', 'mfgId',
       'lotMeth', 'glAcct', 'apDist', 'a0Status', 'a0Func', 'a0Vol', 'a0Off',
       'a1Status', 'a1Func', 'a1Vol', 'a1Off', 'a2Status', 'a2Func', 'a2Vol',
       'a2Off', 'status', 'bHuman', 'lstUseDt', 'lstPIDt', 'a0Start', 'a0End',
       'a1Start', 'a1End', 'a2Start', 'a2End', 'totQStk', 'totQWip', 'totQRes',
       'totQOrd', 'totIqStk', 'totIqWip', 'totIqRes', 'totIqOrd', 'custFld2', 'Unnamed: 66'], axis=1)

# %%
misys.head(50)
# Out:
#              itemId                                              descr  \
# 0       0001-22-046  IDC for Daystar Heater - "K" Series - DSAN & D...
# 1       0001-22-055  Gas Valve, Daystar Heater - "K" Series - DSAN ...
# 2     0002-10-024-2             Transformer, (40VA) for STK 24v Heater
# 3       0002-10-046                            Gas Appliance Connector
# 4       0002-10-132          Gas Appliance Connector, Residential, 36"
# 5   0002-42-006-5.5                Solaronics, Burner Orface, 100K, NG
# 6     0002-42-015-2              Gas Valve for DSAN Heater, Solaronics
# 7     0002-42-024-2                    Transformer-120V. to 24V., 40VA
# 8       0002-42-078                                  Transformer, 75VA
# 9       0002-42-114                      T-stat Guard, Plastic Locking
# 10      0002-42-115                        T-stat Guard, Metal Locking
# 11      0002-42-119                           120V Transformer / Relay
# ...

# %%
##### Create Data Plots Once Data is Clean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
